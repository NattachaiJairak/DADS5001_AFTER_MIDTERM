# %% [markdown]
# <a href="https://colab.research.google.com/github/NattachaiJairak/DADS5001_AFTER_MIDTERM/blob/main/DADS5001_2024-03-16/DADS5001_2024_03_16_Starbucks%20Locations%20Worldwide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Starbucks Locations Worldwide
#
# https://www.kaggle.com/datasets/starbucks/store-locations

# %% [markdown]
# ![2024-05-04 10_27_05-DADS5001_AfterMidterm_Class1_2024-03-16.MOV.png](data:image/png;base64,...)

# %%
import pandas as pd

# URL of the CSV file
url = "https://raw.githubusercontent.com/NattachaiJairak/DADS5001_AFTER_MIDTERM/main/DADS5001_2024-03-16/DADS5001_2024-03-16_In%20Class_SB_directory.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(url)

# Now you can work with the DataFrame 'df'
df  # Display the first few rows of the DataFrame
# Out:
#            Brand  Store Number        Store Name Ownership Type  \
# 0      Starbucks  47370-257954     Meritxell, 96       Licensed
# 1      Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2      Starbucks  47089-256771         Dana Mall       Licensed
# 3      Starbucks  22126-218024        Twofour 54       Licensed
# 4      Starbucks  17127-178586      Al Ain Tower       Licensed
# ...          ...           ...               ...            ...
# 25595  Starbucks  21401-212072               Rex       Licensed
# 25596  Starbucks  24010-226985          Panorama       Licensed
# 25597  Starbucks  47608-253804     Rosebank Mall       Licensed
# 25598  Starbucks  47640-253809      Menlyn Maine       Licensed
# 25599  Starbucks  47609-253286    Mall of Africa       Licensed
#
#                                           Street Address  \
# 0                                      Av. Meritxell, 96
# 1                                   1 Street 69, Al Jarf
# 2                           Sheikh Khalifa Bin Zayed St.
# 3                                        Al Salam Street
# 4                        Khaldiya Area, Abu Dhabi Island
# ...                                                  ...
# 25595  141 Nguyễn Huệ, Quận 1, Góc đường Pasteur và L...
# 25596  SN-44, Tòa Nhà Panorama, 208 Trần Văn Trà, Quận 7
# 25597          Cnr Tyrwhitt and Cradock Avenue, Rosebank
# 25598  Shop 61B, Central Square, Cnr Aramist & Coroba...
# 25599             Shop 2077, Upper Level, Waterfall City
#
#                         City State/Province Country Postcode  Phone Number  \
# 0           Andorra la Vella              7      AD    AD500     376818720
# 1                      Ajman             AJ      AE      NaN           NaN
# 2                      Ajman             AJ      AE      NaN           NaN
# 3                  Abu Dhabi             AZ      AE      NaN           NaN
# 4                  Abu Dhabi             AZ      AE      NaN           NaN
# ...                      ...            ...     ...      ...           ...
# 25595  Thành Phố Hồ Chí Minh             SG      VN    70000  08 3824 4668
# 25596  Thành Phố Hồ Chí Minh             SG      VN    70000  08 5413 8292
# 25597           Johannesburg             GT      ZA     2194   27873500159
# 25598                 Menlyn             GT      ZA      181           NaN
# 25599                Midrand             GT      ZA     1682   27873500215
#
#                              Timezone  Longitude  Latitude
# 0             GMT+1:00 Europe/Andorra       1.53     42.51
# 1                GMT+04:00 Asia/Dubai      55.47     25.42
# 2                GMT+04:00 Asia/Dubai      55.47     25.39
# 3                GMT+04:00 Asia/Dubai      54.38     24.48
# 4                GMT+04:00 Asia/Dubai      54.54     24.51
# ...                               ...        ...       ...
# 25595          GMT+000000 Asia/Saigon     106.70     10.78
# 25596          GMT+000000 Asia/Saigon     106.71     10.72
# 25597  GMT+000000 Africa/Johannesburg      28.04    -26.15
# 25598  GMT+000000 Africa/Johannesburg      28.28    -25.79
# 25599  GMT+000000 Africa/Johannesburg      28.11    -26.02
#
# [25600 rows x 13 columns]

# %%
# Display unique countries and their counts
unique_countries = df['Country'].value_counts()
print("Unique countries in the 'Country' column and their counts:")
unique_countries
# Out:
# Unique countries in the 'Country' column and their counts:
# Country
# US    13608
# CN     2734
# CA     1468
# JP     1237
# KR      993
#       ...
# CW        3
# AW        3
# MC        2
# LU        2
# AD        1
# Name: count, Length: 73, dtype: int64

# %%
# Filter for entries where the country code is "TH"
thailand_data = df[df['Country'] == 'TH']

# Display the filtered data
thailand_data
# Out:
#            Brand  Store Number                Store Name Ownership Type  \
# 10952  Starbucks  32359-136499          The Mall Bangkae  Company Owned
# 10953  Starbucks   2046-141768                       CDC  Company Owned
# 10954  Starbucks   1478-142236         Vejthani Hospital  Company Owned
# 10955  Starbucks  17707-182486    The Scene Town in Town  Company Owned
# 10956  Starbucks  33741-253264     The Mall Bangkapi G/F  Company Owned
# ...          ...           ...                       ...            ...
# 11236  Starbucks  20838-188467  Central Festival Hat Yai  Company Owned
# 11237  Starbucks   33754-97972           Tuk Com Pattaya  Company Owned
# 11238  Starbucks  33761-143431      Royal Garden Pattaya  Company Owned
# 11239  Starbucks   33718-28447                   Pattaya  Company Owned
# 11240  Starbucks   1967-136510  Central Festival Pattaya  Company Owned
#
#                                           Street Address        City  \
# 10952  275, G Zone Fashion Hall 1, Moo 1, Petchakasem...     Bangkae
# 10953  Crytal Design Center, Room No.Z2.143, Soi Lard...    Bangkapi
# 10954  Vejthani Hospital, No.1, Soi Lardprao 111, Lar...    Bangkapi
# 10955  Sriwara Road, Wana Thong Lang, Sriwara Road,, ...    Bangkapi
# 10956  3522, Food Center G Floor, The Mall Bangkapi, ...    Bangkapi
# ...                                                  ...         ...
# 11236       Central Had Yai, Karnjanavanit Road, Hat Yai    Songkhla
# 11237                       8, Moo 10 South Pattaya Road  Banglamung
# 11238                             218, Moo 10 Beach Road  Banglamung
# 11239               219/3, Yamamoto 13/1 Soi  Beach Road  Banglamung
# 11240  Unit 156, Central Festival Pattaya Beach, 333/...  Banglamung
#
#       State/Province Country Postcode Phone Number                Timezone  \
# 10952             10      TH    10160    844387432  GMT+07:00 Asia/Bangkok
# 10953             10      TH    10240    819393806  GMT+07:00 Asia/Bangkok
# 10954             10      TH    10240    844387449  GMT+07:00 Asia/Bangkok
# 10955             10      TH    10310    847517727  GMT+07:00 Asia/Bangkok
# 10956             10      TH    10240    844387362  GMT+07:00 Asia/Bangkok
# ...              ...     ...      ...          ...                     ...
# 11236             90      TH    90110    922798164  GMT+07:00 Asia/Bangkok
# 11237              S      TH    20150    844387374  GMT+07:00 Asia/Bangkok
# 11238              S      TH    20260    844387377  GMT+07:00 Asia/Bangkok
# 11239              S      TH    20150    844387331  GMT+07:00 Asia/Bangkok
# 11240              S      TH    20150    844387451  GMT+07:00 Asia/Bangkok
#
#        Longitude  Latitude
# 10952     100.41     13.71
# 10953     100.62     13.80
# 10954     100.64     13.77
# 10955     100.61     13.77
# 10956     100.64     13.77
# ...          ...       ...
# 11236     100.48      6.99
# 11237     100.88     12.92
# 11238     100.88     12.93
# 11239     100.88     12.93
# 11240     100.88     12.93
#
# [289 rows x 13 columns]

# %%
import plotly.express as px

# %%
# Filter the DataFrame for stores in Thailand, Malaysia, Singapore, and Indonesia
stores_by_country = df[df['Country'].isin(['TH', 'MY', 'SG', 'ID'])]

# Count the number of stores by country
store_counts = stores_by_country['Country'].value_counts().reset_index()
store_counts.columns = ['Country', 'Number of Stores']

# Create a bar chart using Plotly
fig = px.bar(store_counts, x='Country', y='Number of Stores', color='Country',
             title='Number of Stores by Country',
             labels={'Number of Stores': 'Number of Stores'},
             text='Number of Stores')  # Add count as text above each bar
fig.update_traces(texttemplate='%{text}', textposition='outside')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1ccad88e-91bc-47d6-90f7-5459da38a9c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ccad88e-91bc-47d6-90f7-5459da38a9c0")) {                    Plotly.newPlot(                        "1ccad88e-91bc-47d6-90f7-5459da38a9c0",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eNumber of Stores=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TH","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"TH","offsetgroup":"TH","orientation":"v","showlegend":true,"text":[282.0],"textposition":"outside","x":["TH"],"xaxis":"x","y":[282],"yaxis":"y","type":"bar","texttemplate":"%{text}"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eNumber of Stores=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MY","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"MY","offsetgroup":"MY","orientation":"v","showlegend":true,"text":[226.0],"textposition":"outside","x":["MY"],"xaxis":"x","y":[226],"yaxis":"y","type":"bar","texttemplate":"%{text}"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eNumber of Stores=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ID","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"ID","offsetgroup":"ID","orientation":"v","showlegend":true,"text":[215.0],"textposition":"outside","x":["ID"],"xaxis":"x","y":[215],"yaxis":"y","type":"bar","texttemplate":"%{text}"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eNumber of Stores=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SG","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"SG","offsetgroup":"SG","orientation":"v","showlegend":true,"text":[126.0],"textposition":"outside","x":["SG"],"xaxis":"x","y":[126],"yaxis":"y","type":"bar","texttemplate":"%{text}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...

# %%
# Remove rows with missing 'Postcode' or 'Country' values
df = df.dropna(subset=['Postcode', 'Country'])

# Convert 'Postcode' column to integers
df['Postcode'] = pd.to_numeric(df['Postcode'], errors='coerce')

# Filter the DataFrame for country code "TH" (Thailand) and postcodes between 50000 and 51000
filtered_df = df[(df['Country'] == 'TH') & (df['Postcode'] >= 50000) & (df['Postcode'] <= 51000)].copy()

# Add a new column 'Number of Stores' with a constant value (1 for each store)
filtered_df.loc[:, 'Number of Stores'] = 1

# Create a map using Plotly
fig = px.scatter_geo(filtered_df, lat='Latitude', lon='Longitude', color='Country',
                     title='Locations in Thailand (Postcode 50000 - 51000)',
                     projection='natural earth', hover_name='Store Name',
                     hover_data={'Number of Stores': True, 'Postcode': True})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="71a2b551-f351-4111-bb06-3860879bcb85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71a2b551-f351-4111-bb06-3860879bcb85")) {                    Plotly.newPlot(                        "71a2b551-f351-4111-bb06-3860879bcb85",                        [{"customdata":[[1.0,50000.0],[1.0,50000.0],[1.0,50200.0],[1.0,50200.0],[1.0,50230.0],[1.0,50200.0],[1.0,50200.0],[1.0,50300.0],[1.0,50000.0],[1.0,50200.0]],"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=TH\u003cbr\u003eLatitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cbr\u003eNumber of Stores=%{customdata[0]}\u003cbr\u003ePostcode=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Central Festival Chiang Mai","Maya Chiang Mai","Chiangmai Ram Hospital","Chiangmai Airport","Kad Farang","Chiangmai","Chiangmai Nimmanhemin","Chiangmai Tha Pae","Chiangmai2","Kad Suan Kaew"],"lat":[18.8,18.8,18.79,18.77,18.7,18.78,18.8,18.79,18.77,18.8],"legendgroup":"TH","lon":[99.02,98.97,98.98,98.97,98.93,99.0,98.97,98.99,98.98,98.98],"marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"TH","showlegend":true,"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}] ...

# %%
import pandas as pd

# Assuming 'filtered_df' is your filtered DataFrame
table_data = filtered_df[['Store Name', 'Postcode', 'Latitude', 'Longitude', 'Number of Stores']]

# Display the table
table_data
# Out:
#                         Store Name  Postcode  Latitude  Longitude  \
# 11198  Central Festival Chiang Mai   50000.0     18.80      99.02
# 11199              Maya Chiang Mai   50000.0     18.80      98.97
# 11200       Chiangmai Ram Hospital   50200.0     18.79      98.98
# 11201            Chiangmai Airport   50200.0     18.77      98.97
# 11202                   Kad Farang   50230.0     18.70      98.93
# 11203                    Chiangmai   50200.0     18.78      99.00
# 11204        Chiangmai Nimmanhemin   50200.0     18.80      98.97
# 11205            Chiangmai Tha Pae   50300.0     18.79      98.99
# 11206                   Chiangmai2   50000.0     18.77      98.98
# 11207                Kad Suan Kaew   50200.0     18.80      98.98
#
#        Number of Stores
# 11198                 1
# 11199                 1
# 11200                 1
# 11201                 1
# 11202                 1
# 11203                 1
# 11204                 1
# 11205                 1
# 11206                 1
# 11207                 1
