# %% [markdown]
# - https://github.com/ccxt/ccxt
# - https://www.nytimes.com/interactive/2016/08/08/sports/olympics/history-olympic-dominance-charts.html
# - https://dune.com/browse/dashboards

# %%
import requests
import plotly.express as px
import pandas as pd


#Document of Binance API
#https://binance-docs.github.io/apidocs/spot/en/#rolling-window-price-change-statistics
#coin = 'BTCUSDT'
#key = "https://api.binance.com/api/v3/ticker?symbol="+coin
#Example using on website: https://api.binance.com/api/v3/ticker?symbol=BTCUSDT&type=MINI&windowSize=1m

#symbol = 'BTCUSDT&type=MINI&windowSize=1m'
symbol = 'BTCUSDT&type=MINI'
api = "https://api.binance.com/api/v3/ticker?symbol="+symbol


data = requests.get(api).json()
print(data)

price = float(data['lastPrice'])
#print(price)

closeTime = data['closeTime']
#print(closeTime)
# Out:
# {'symbol': 'BTCUSDT', 'openPrice': '66928.38000000', 'highPrice': '71561.10000000', 'lowPrice': '66928.38000000', 'lastPrice': '70716.43000000', 'volume': '55960.19805000', 'quoteVolume': '3919550537.06790870', 'openTime': 1711373400000, 'closeTime': 1711459856371, 'firstId': 3512119019, 'lastId': 3514867810, 'count': 2748792}

# %% [markdown]
# โค้ดด้านบนเป็นโปรแกรม Python ที่ใช้สำหรับดึงข้อมูลราคาล่าสุดของเหรียญดิจิตอลจาก Binance API และแสดงผลในรูปแบบของ JSON ก่อนที่จะทำการประมวลผลข้อมูลนั้นเพื่อใช้ในการพล็อตกราฟด้วย Plotly Express library ของ Python
#
# อย่างละเอียดแต่ละบรรทัดดังนี้:
#
# 1. `import requests`: นำเข้าโมดูล requests เพื่อใช้สำหรับการส่งคำขอ HTTP ไปยังเว็บไซต์เพื่อดึงข้อมูล
#
# 2. `import plotly.express as px`: นำเข้าโมดูล plotly.express โดยให้ตั้งชื่อย่อเป็น px เพื่อใช้สำหรับการพล็อตกราฟ
#
# 3. `import pandas as pd`: นำเข้าโมดูล pandas โดยให้ตั้งชื่อย่อเป็น pd เพื่อใช้สำหรับการจัดการข้อมูลในรูปแบบของ DataFrame
#
# 4. คอมเมนต์เกี่ยวกับเอกสาร API ของ Binance ซึ่งจะบันทึก URL ของเอกสาร API ไว้เพื่ออ้างอิงในภายหลัง
#
# 5. กำหนดตัวแปร `symbol` เป็น `'BTCUSDT&type=MINI'` ซึ่งเป็นสตริงที่ใช้สำหรับสร้าง URL สำหรับการเรียกข้อมูล API โดยระบุสัญลักษณ์ของคู่เงินและประเภทของข้อมูลที่ต้องการ (ในที่นี้คือ MINI)
#
# 6. กำหนดตัวแปร `api` เพื่อเก็บ URL ของ API โดยรวมกับ `symbol` ที่กำหนดไว้ในข้อ 5
#
# 7. ใช้ requests.get() เพื่อส่งคำขอ GET ไปยัง URL ที่ระบุในตัวแปร `api` และใช้ `.json()` เพื่อแปลงข้อมูลที่ได้รับกลับมาจากรูปแบบ JSON เป็น dictionary และเก็บไว้ในตัวแปร `data`
#
# 8. พิมพ์ค่าของ `data` ที่ได้รับกลับมา ซึ่งจะเป็นข้อมูลราคาล่าสุดของเหรียญดิจิตอลที่เราร้องขอ
#
# 9. นำค่าราคาล่าสุดของเหรียญดิจิตอลที่ได้รับมาจาก `data` และเก็บไว้ในตัวแปร `price` โดยแปลงค่าให้อยู่ในรูปแบบของจำนวนทศนิยม (float)
#
# 10. คอมเมนต์ไว้เพื่อแสดงค่าของ `price` ที่ได้หลังจากการแปลง
#
# 11. เก็บค่าของ `closeTime` ที่ได้จาก `data` ในตัวแปร `closeTime`
#
# 12. คอมเมนต์ไว้เพื่อแสดงค่าของ `closeTime` ที่ได้หลังจากการเก็บค่า

# %% [markdown]
# symbol = 'BTCUSDT&type=MINI&windowSize=1m'
#
# ตัวแปร `symbol` ถูกกำหนดค่าเป็น `'BTCUSDT&type=MINI&windowSize=1m'` ซึ่งเป็นสตริงที่ใช้สำหรับสร้าง URL สำหรับการเรียกข้อมูล API โดยมีรายละเอียดดังนี้:
#
# - `'BTCUSDT'`: คือสัญลักษณ์ของคู่เงิน (BTC/USDT) ที่ต้องการดึงข้อมูล
# - `'type=MINI'`: คือประเภทของข้อมูลที่ต้องการ ซึ่งในที่นี้เป็น MINI ซึ่งอาจหมายถึงข้อมูลที่เล็กน้อยหรือเพียงส่วนหนึ่งของข้อมูลทั้งหมด
# - `'windowSize=1m'`: คือขนาดของหน้าต่างเวลาที่ต้องการข้อมูล ซึ่งในที่นี้เป็น 1 นาที (1 minute) ซึ่งหมายถึงเราต้องการข้อมูลราคาทุกนาทีของเหรียญดิจิตอลนั้นๆ
#
# ดังนั้น URL ที่ถูกสร้างจากการรวม `symbol` กับ URL ของ Binance API จะเป็นเช่นนี้:
#
# ```
# https://api.binance.com/api/v3/ticker?symbol=BTCUSDT&type=MINI&windowSize=1m
# ```
#
# ซึ่ง URL นี้จะใช้ในการเรียกข้อมูลราคาล่าสุดของคู่เงิน BTC/USDT โดยเน้นที่ข้อมูลที่เล็กน้อยและราคาทุกนาทีในช่วงเวลาที่กำหนด

# %%
data
# Out:
# {'symbol': 'BTCUSDT',
#  'openPrice': '66928.38000000',
#  'highPrice': '71561.10000000',
#  'lowPrice': '66928.38000000',
#  'lastPrice': '70716.43000000',
#  'volume': '55960.19805000',
#  'quoteVolume': '3919550537.06790870',
#  'openTime': 1711373400000,
#  'closeTime': 1711459856371,
#  'firstId': 3512119019,
#  'lastId': 3514867810,
#  'count': 2748792}

# %%
price
# Out:
# 70716.43

# %%
closeTime
# Out:
# 1711459856371

# %% [markdown]
# ![2024-03-26%2021_03_06-DADS5001_AfterMidterm_Class2_2024-03-23.MOV.png](attachment:2024-03-26%2021_03_06-DADS5001_AfterMidterm_Class2_2024-03-23.MOV.png)

# %% [markdown]
# https://www.epochconverter.com/
#
# Epoch & Unix Timestamp Conversion Tools

# %%
import requests
import pandas as pd
import plotly.express as px

# Define the coins and create an empty list to store data
coins = ['BTCUSDT', 'ETHUSDT', 'BNBUSDT']
data_list = []

# Loop through each coin to fetch data
for coin in coins:
    api = f"https://api.binance.com/api/v3/ticker/24hr?symbol={coin}"
    data = requests.get(api).json()
    # Extract price and volume data (modify as needed)
    data_list.append({'coin': coin, 'price': float(data['lastPrice']), 'volume': float(data['volume'])})

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(data_list)

# Now, df contains the last price and volume of each coin
# You can plot this data using plotly

# For Price Comparison
fig_price = px.line(df, x='coin', y='price', title='Price Comparison of Cryptocurrencies')
fig_price.show()

# For Volume Comparison
fig_volume = px.line(df, x='coin', y='volume', title='Volume Comparison of Cryptocurrencies')
fig_volume.show()
# Out:
# <div>                            <div id="d929e777-19c5-4928-830f-867112a7dc0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d929e777-19c5-4928-830f-867112a7dc0a")) {                    Plotly.newPlot(                        "d929e777-19c5-4928-830f-867112a7dc0a",                        [{"hovertemplate":"coin=%{x}<br>price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["BTCUSDT","ETHUSDT","BNBUSDT"],"xaxis":"x","y":[70703.98,3620.64,587.2],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[
# ...

# %% [markdown]
# โค้ดด้านบนเป็นโปรแกรม Python ที่ใช้สำหรับดึงข้อมูลราคาและปริมาณการซื้อขายของสกุลเงิน cryptocurrency จาก Binance API และพล็อตกราฟเส้นเพื่อเปรียบเทียบราคาและปริมาณการซื้อขายของสกุลเงิน cryptocurrency ต่าง ๆ ที่กำหนด (ในที่นี้คือ Bitcoin (BTC), Ethereum (ETH), และ Binance Coin (BNB)) โดยมีขั้นตอนการทำงานดังนี้:
#
# 1. นำเข้าไลบรารีที่จำเป็น: requests เพื่อทำ HTTP requests เพื่อเรียกข้อมูลจาก API, pandas เพื่อจัดการข้อมูลในรูปแบบ DataFrame, และ plotly.express เพื่อพล็อตกราฟ.
#
# 2. กำหนดรายการสกุลเงิน cryptocurrency ที่ต้องการดึงข้อมูลราคาและปริมาณการซื้อขาย.
#
# 3. ใช้ลูป `for` เพื่อดึงข้อมูลราคาและปริมาณการซื้อขายของสกุลเงิน cryptocurrency แต่ละตัว โดยวนลูปผ่านรายการสกุลเงิน cryptocurrency.
#
# 4. สร้าง URL สำหรับเรียก API ของ Binance โดยใช้รหัสสัญลักษณ์ของสกุลเงิน cryptocurrency แต่ละตัวและทำ HTTP GET request เพื่อดึงข้อมูล.
#
# 5. แปลงข้อมูลที่ได้รับจาก API ให้เป็น JSON format และนำมาใช้ในการสร้างราคาและปริมาณการซื้อขายปัจจุบันของสกุลเงิน cryptocurrency.
#
# 6. เพิ่มข้อมูลราคาและปริมาณการซื้อขายปัจจุบันลงในรายการข้อมูล.
#
# 7. หลังจากได้ข้อมูลทั้งหมด ให้แปลงรายการข้อมูลเป็น DataFrame โดยใช้ pandas.
#
# 8. ใช้ Plotly Express เพื่อพล็อตกราฟเส้นเพื่อเปรียบเทียบราคาและปริมาณการซื้อขายของสกุลเงิน cryptocurrency ต่าง ๆ ตามเวลา.
#
# 9. แสดงกราฟที่ได้ผลลัพธ์.
#
# โค้ดนี้จะสร้างกราฟเส้นเพื่อแสดงการเปรียบเทียบราคาและปริมาณการซื้อขายของสกุลเงิน cryptocurrency ต่าง ๆ ตลอดเวลาที่กำหนด ในที่นี้คือ 10 รอบการดึงข้อมูลแต่ละครั้งที่มีการหน่วงเวลา 1 วินาทีก่อนการดึงข้อมูลต่อไป

# %%
import requests
import pandas as pd
import time

# List of cryptocurrencies
cryptos = ['BTCUSDT', 'ETHUSDT', 'BNBUSDT']  # Add more if needed

# Loop 10 times
for i in range(1, 11):
    print(f"Loop {i}:")
    for crypto in cryptos:
        api_url = f"https://api.binance.com/api/v3/ticker/price?symbol={crypto}"
        response = requests.get(api_url)
        data = response.json()

        print(f"Crypto: {crypto}, Price: {data['price']}, Timestamp: {time.time()}")

    # Wait for 1 second before next fetch
    time.sleep(1)
# Out:
# Loop 1:
# Crypto: BTCUSDT, Price: 70608.40000000, Timestamp: 1711461361.0136352
# Crypto: ETHUSDT, Price: 3617.57000000, Timestamp: 1711461361.1610014
# Crypto: BNBUSDT, Price: 586.90000000, Timestamp: 1711461361.3016343
# Loop 2:
# Crypto: BTCUSDT, Price: 70600.01000000, Timestamp: 1711461362.4514604
# Crypto: ETHUSDT, Price: 3617.17000000, Timestamp: 1711461362.591979
# Crypto: BNBUSDT, Price: 586.90000000, Timestamp: 1711461362.7302756
# Loop 3:
# Crypto: BTCUSDT, Price: 70600.00000000, Timestamp: 1711461363.877153
# Crypto: ETHUSDT, Price: 3616.89000000, Timestamp: 1711461364.014809
# Crypto: BNBUSDT, Price: 586.90000000, Timestamp: 1711461364.1535516
# Loop 4:
# Crypto: BTCUSDT, Price: 70600.00000000, Timestamp: 1711461365.3023725
# Crypto: ETHUSDT, Price: 3616.73000000, Timestamp: 1711461365.4374495
# Crypto: BNBUSDT, Price: 586.90000000, Timestamp: 1711461365.593854
# Loop 5:
# Crypto: BTCUSDT, Price: 70570.84000000, Timestamp: 1711461366.736803
# ...

# %% [markdown]
# โค้ดด้านบนเป็นโปรแกรม Python ที่ดึงข้อมูลราคาของสกุลเงิน cryptocurrency จาก Binance API และพิมพ์ผลลัพธ์ออกทางหน้าจอ โดยจะทำการดึงข้อมูลใหม่ทุกๆ 1 วินาที เป็นจำนวน 10 รอบ โดยมีขั้นตอนการทำงานดังนี้:
#
# 1. นำเข้าไลบรารีที่จำเป็น: requests เพื่อทำ HTTP requests เพื่อเรียกข้อมูลจาก API, pandas เพื่อจัดการข้อมูลในรูปแบบ DataFrame, และ time เพื่อใช้ในการหน่วงเวลา.
#
# 2. กำหนดรายการของสกุลเงิน cryptocurrency ที่ต้องการดึงข้อมูลราคา.
#
# 3. ใช้ลูป `for` เพื่อทำการดึงข้อมูลราคาของสกุลเงิน cryptocurrency ทุกตัวในรายการ.
#
# 4. สร้าง URL สำหรับเรียก API ของ Binance โดยใช้รหัสสัญลักษณ์ของสกุลเงิน cryptocurrency แต่ละตัวและทำ HTTP GET request เพื่อดึงข้อมูล.
#
# 5. แปลงข้อมูลที่ได้รับจาก API ให้เป็น JSON format และพิมพ์ผลลัพธ์ออกทางหน้าจอโดยแสดงราคาของสกุลเงิน cryptocurrency และเวลาปัจจุบัน.
#
# 6. หลังจากพิมพ์ผลลัพธ์ทุกตัวในรอบนั้นๆ เสร็จสิ้น รอเวลา 1 วินาทีโดยใช้ `time.sleep(1)` ก่อนที่จะดึงข้อมูลใหม่ในรอบถัดไป.
#
# โปรดทราบว่าในการดึงข้อมูลทุกๆ 1 วินาที และรอบการดึงข้อมูลทั้งหมด 10 รอบ จะทำให้โปรแกรมทำงานโดยรวดเร็วและแสดงผลข้อมูลล่าสุดของสกุลเงิน cryptocurrency ในแต่ละรอบการดึงข้อมูลได้อย่างครบถ้วนและทันท่วงที

# %%
import requests
import pandas as pd
import time
import plotly.express as px

# Initialize a DataFrame to store the data
data_columns = ['Timestamp', 'Crypto', 'Price']
data_list = []

# List of cryptocurrencies
cryptos = ['BTCUSDT', 'ETHUSDT', 'BNBUSDT']  # Add more if needed

# Fetch data for a certain duration or number of iterations
for _ in range(5):  # For example, run for 5 iterations
    temp_data_list = []
    for crypto in cryptos:
        api_url = f"https://api.binance.com/api/v3/ticker/price?symbol={crypto}"
        response = requests.get(api_url)
        data = response.json()

        # Append the data to the temporary list
        current_time = pd.Timestamp.now()
        temp_data_list.append([current_time, crypto, float(data['price'])])

        time.sleep(1)  # Wait for 1 second before next fetch
    
    # Append the temporary list to the main list
    data_list.extend(temp_data_list)

# Convert the list of data to a DataFrame
data_df = pd.DataFrame(data_list, columns=data_columns)

# Plotting
fig = px.line(data_df, x='Timestamp', y='Price', color='Crypto', title='Cryptocurrency Prices Over Time')
fig.show()
# Out:
# C:\Users\Nattachai Jairak\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# C:\Users\Nattachai Jairak\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# ...

# %% [markdown]
# โค้ดด้านบนเป็นโปรแกรม Python ที่ใช้สำหรับดึงข้อมูลราคา cryptocurrency จาก Binance API และพล็อตกราฟแสดงราคาของ cryptocurrency ต่าง ๆ ตลอดเวลา โดยมีขั้นตอนการทำงานดังนี้:
#
# 1. นำเข้าไลบรารีที่จำเป็น: requests เพื่อทำ HTTP requests เพื่อเรียกข้อมูลจาก API, pandas เพื่อจัดการข้อมูลในรูปแบบ DataFrame, time เพื่อทำการหน่วงเวลา, และ plotly.express เพื่อพล็อตกราฟ.
#
# 2. สร้าง DataFrame เปล่าๆ สำหรับเก็บข้อมูลโดยกำหนดชื่อคอลัมน์เป็น ['Timestamp', 'Crypto', 'Price'].
#
# 3. กำหนดรายการ cryptocurrencies ที่ต้องการดึงข้อมูลราคา.
#
# 4. ใช้ลูป `for` เพื่อดึงข้อมูลราคา cryptocurrency จาก Binance API โดยวนลูปเป็นจำนวนรอบที่กำหนด (ในที่นี้คือ 5 รอบ).
#
# 5. ภายในลูป `for` นอกสุด มีลูป `for` ซ้อนอยู่ เพื่อดึงข้อมูลราคาของแต่ละ cryptocurrency ในรายการ.
#
# 6. สร้าง URL สำหรับเรียก API ของ Binance โดยระบุ symbol ของ cryptocurrency และทำ HTTP GET request เพื่อดึงข้อมูล.
#
# 7. แปลงข้อมูลที่ได้รับจาก API ให้เป็น JSON format และนำมาใช้ในการสร้างราคา cryptocurrency ปัจจุบัน.
#
# 8. เพิ่มข้อมูลราคา cryptocurrency ปัจจุบันที่ได้รับลงในรายการชั่วคราว (temp_data_list) พร้อมกับ Timestamp ปัจจุบันและชื่อ cryptocurrency.
#
# 9. หยุดรอเพื่อระหว่างการดึงข้อมูลแต่ละรอบด้วย `time.sleep(1)` เพื่อให้มีการหน่วงเวลา 1 วินาที.
#
# 10. เมื่อได้ข้อมูลทั้งหมดของ cryptocurrency ทุกตัวในรอบนั้นๆ จะนำรายการชั่วคราวไปต่อท้ายรายการหลัก (data_list).
#
# 11. หลังจากลูป `for` นอกสุดเสร็จสิ้น จะมีขั้นตอนที่ใช้เสร็จสำหรับแปลงรายการข้อมูล (data_list) ให้เป็น DataFrame โดยระบุคอลัมน์ตามชื่อที่กำหนด.
#
# 12. ใช้ Plotly Express เพื่อพล็อตกราฟเส้นของ cryptocurrency แต่ละตัวตามราคาและ Timestamp ที่ได้จาก DataFrame.
#
# 13. แสดงกราฟที่ได้ผลลัพธ์.
#
# โค้ดนี้ทำหน้าที่ดึงข้อมูลราคา cryptocurrency จาก Binance API และพล็อตกราฟแสดงการเปรียบเทียบราคาของ cryptocurrency ต่าง ๆ ตลอดเวลาที่กำหนด ในที่นี้คือ 5 รอบ โดยระบบจะหยุดการทำงานหลังจากผ่านไป 5 รอบการดึงข้อมูล และแสดงกราฟออกทางหน้าจอ.

# %%
import requests
import pandas as pd
import time
import plotly.express as px

# Initialize an empty list to store data
data_list = []

# List of cryptocurrencies
cryptos = ['BTCUSDT', 'ETHUSDT', 'BNBUSDT']  # Add more if needed

# Fetch data for a certain duration or number of iterations
for _ in range(10):  # For example, run for 10 iterations
    for crypto in cryptos:
        api_url = f"https://api.binance.com/api/v3/ticker/24hr?symbol={crypto}"
        response = requests.get(api_url)
        data = response.json()

        # Append data to the list
        current_time = pd.Timestamp.now()
        data_list.append({'Timestamp': current_time, 'Crypto': crypto,
                          'Price': float(data['lastPrice']),
                          'Volume': float(data['volume'])})

        time.sleep(1)  # Wait for 1 second before next fetch

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(data_list)

# Plotting Price
fig_price = px.line(df, x='Timestamp', y='Price', color='Crypto', title='Cryptocurrency Prices Over Time')
fig_price.show()

# Plotting Volume
fig_volume = px.line(df, x='Timestamp', y='Volume', color='Crypto', title='Cryptocurrency Volumes Over Time')
fig_volume.show()
# Out:
# C:\Users\Nattachai Jairak\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# C:\Users\Nattachai Jairak\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# ...

# %% [markdown]
# โค้ดด้านบนเป็นโปรแกรม Python ที่ใช้สำหรับดึงข้อมูลราคาและปริมาณการซื้อขายของ cryptocurrency จาก Binance API และพล็อตกราฟเส้นแสดงการเปรียบเทียบราคาและปริมาณการซื้อขายของ cryptocurrency ต่าง ๆ ตลอดเวลาที่กำหนด (ในที่นี้คือ 10 รอบ) โดยมีขั้นตอนการทำงานดังนี้:
#
# 1. นำเข้าไลบรารีที่จำเป็น: requests เพื่อทำ HTTP requests เพื่อเรียกข้อมูลจาก API, pandas เพื่อจัดการข้อมูลในรูปแบบ DataFrame, time เพื่อทำการหน่วงเวลา, และ plotly.express เพื่อพล็อตกราฟ.
#
# 2. สร้างรายการว่างเพื่อเก็บข้อมูล.
#
# 3. กำหนดรายการ cryptocurrencies ที่ต้องการดึงข้อมูลราคาและปริมาณการซื้อขาย.
#
# 4. ใช้ลูป `for` เพื่อดึงข้อมูลราคาและปริมาณการซื้อขายของ cryptocurrency จาก Binance API โดยวนลูปเป็นจำนวนรอบที่กำหนด (ในที่นี้คือ 10 รอบ).
#
# 5. ภายในลูป `for` นอกสุด มีลูป `for` ซ้อนอยู่ เพื่อดึงข้อมูลราคาและปริมาณการซื้อขายของแต่ละ cryptocurrency ในรายการ.
#
# 6. สร้าง URL สำหรับเรียก API ของ Binance โดยระบุ symbol ของ cryptocurrency และทำ HTTP GET request เพื่อดึงข้อมูล.
#
# 7. แปลงข้อมูลที่ได้รับจาก API ให้เป็น JSON format และนำมาใช้ในการสร้างราคาและปริมาณการซื้อขายปัจจุบันของ cryptocurrency.
#
# 8. เพิ่มข้อมูลราคาและปริมาณการซื้อขายปัจจุบันลงในรายการ.
#
# 9. หยุดรอเพื่อระหว่างการดึงข้อมูลแต่ละรอบด้วย `time.sleep(1)` เพื่อให้มีการหน่วงเวลา 1 วินาที.
#
# 10. เมื่อได้ข้อมูลทั้งหมดของ cryptocurrency ทุกตัวในรอบนั้นๆ จะนำรายการไปแปลงเป็น DataFrame.
#
# 11. ใช้ Plotly Express เพื่อพล็อตกราฟเส้นแสดงการเปรียบเทียบราคาและปริมาณการซื้อขายของ cryptocurrency ตามเวลา.
#
# 12. แสดงกราฟที่ได้ผลลัพธ์.
#
# โค้ดนี้ทำหน้าที่ดึงข้อมูลราคาและปริมาณการซื้อขายของ cryptocurrency จาก Binance API และพล็อตกราฟเส้นเพื่อแสดงการเปรียบเทียบราคาและปริมาณการซื้อขายของ cryptocurrency ต่าง ๆ ตลอดเวลาที่กำหนด (ในที่นี้คือ 10 รอบ
